# %% [markdown]
# # Parte 5 — Bonus: LoRA sobre BERTweet
# ### Workshop: Clasificación de Emociones en Twitter
#
# BERTweet tiene ~110M parámetros — el doble que DistilBERT. LoRA permite adaptarlo con una fracción mínima de los parámetros.
#
# BERTweet usa la arquitectura de BERT, cuyas proyecciones de atención tienen nombres distintos a DistilBERT:
#
# | Modelo | Proyecciones |
# |---|---|
# | DistilBERT | `q_lin`, `k_lin`, `v_lin`, `out_lin` |
# | BERTweet / BERT | `query`, `key`, `value`, `dense` |
#
# **Prerequisito:** haber ejecutado `part-1-data.ipynb` y `part-2-pipeline.ipynb`

# %%
# !pip install peft -q
# %run tweeteval-part-2-pipeline.ipynb
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 3257
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 1421
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 374
#     })
# })
# compute_metrics OK
# make_tokenized_dataset OK
# full_evaluation OK
# plot_training_curves OK
# make_trainer OK
#
# Pipeline lista. Puedes continuar con part-3-distilbert.ipynb

# %%
from peft import LoraConfig, get_peft_model, TaskType

MODEL_CHECKPOINT = "vinai/bertweet-base"
HF_REPO          = "isabeljuradoj27/tweeteval-emotion-bertweet-lora"  # <-- cambia esto
LR_LORA          = 2e-4   # más alto que full FT — pocos parámetros entrenables

# %% [markdown]
# ## Dataset tokenizado
#
# Reutilizamos el tokenizador de BERTweet del experimento anterior.

# %%
from transformers import AutoTokenizer

tok_bertweet = AutoTokenizer.from_pretrained(MODEL_CHECKPOINT, normalization=True)
ds_bertweet  = make_tokenized_dataset(tok_bertweet)
print(ds_bertweet)
# Out:
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 3257
#     })
#     test: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 1421
#     })
#     validation: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 374
#     })
# })

# %% [markdown]
# ## Inspección de módulos
#
# Antes de aplicar LoRA, inspeccionamos los nombres de las capas lineales de BERTweet.

# %%
from transformers import AutoModelForSequenceClassification

base_bt = AutoModelForSequenceClassification.from_pretrained(
    MODEL_CHECKPOINT, num_labels=NUM_LABELS,
    id2label=ID2LABEL, label2id=LABEL2ID)

print("Módulos lineales de BERTweet:")
for name, module in base_bt.named_modules():
    if isinstance(module, torch.nn.Linear):
        print(f"  {name}  [{module.in_features} → {module.out_features}]")
# Out:
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: vinai/bertweet-base
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.decoder.weight          | UNEXPECTED |
# lm_head.decoder.bias            | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# roberta.pooler.dense.bias       | UNEXPECTED |
# roberta.pooler.dense.weight     | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# classifier.dense.bias           | MISSING    |
# classifier.out_proj.bias        | MISSING    |
# classifier.out_proj.weight      | MISSING    |
# classifier.dense.weight         | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Módulos lineales de BERTweet:
#   roberta.encoder.layer.0.attention.self.query  [768 → 768]
#   roberta.encoder.layer.0.attention.self.key  [768 → 768]
#   roberta.encoder.layer.0.attention.self.value  [768 → 768]
#   roberta.encoder.layer.0.attention.output.dense  [768 → 768]
#   roberta.encoder.layer.0.intermediate.dense  [768 → 3072]
#   roberta.encoder.layer.0.output.dense  [3072 → 768]
#   roberta.encoder.layer.1.attention.self.query  [768 → 768]
#   roberta.encoder.layer.1.attention.self.key  [768 → 768]
#   roberta.encoder.layer.1.attention.self.value  [768 → 768]
#   roberta.encoder.layer.1.attention.output.dense  [768 → 768]
#   roberta.encoder.layer.1.intermediate.dense  [768 → 3072]
#   roberta.encoder.layer.1.output.dense  [3072 → 768]
#   roberta.encoder.layer.2.attention.self.query  [768 → 768]
#   roberta.encoder.layer.2.attention.self.key  [768 → 768]
#   roberta.encoder.layer.2.attention.self.value  [768 → 768]
#   roberta.encoder.layer.2.attention.output.dense  [768 → 768]
#   roberta.encoder.layer.2.intermediate.dense  [768 → 3072]
#   roberta.encoder.layer.2.output.dense  [3072 → 768]
#   roberta.encoder.layer.3.attention.self.query  [768 → 768]
#   roberta.encoder.layer.3.attention.self.key  [768 → 768]
#   roberta.encoder.layer.3.attention.self.value  [768 → 768]
#   roberta.encoder.layer.3.attention.output.dense  [768 → 768]
#   roberta.encoder.layer.3.intermediate.dense  [768 → 3072]
#   roberta.encoder.layer.3.output.dense  [3072 → 768]
#   roberta.encoder.layer.4.attention.self.query  [768 → 768]
#   roberta.encoder.layer.4.attention.self.key  [768 → 768]
#   roberta.encoder.layer.4.attention.self.value  [768 → 768]
#   roberta.encoder.layer.4.attention.output.dense  [768 → 768]
#   roberta.encoder.layer.4.intermediate.dense  [768 → 3072]
#   roberta.encoder.layer.4.output.dense  [3072 → 768]
#   roberta.encoder.layer.5.attention.self.query  [768 → 768]
#   roberta.encoder.layer.5.attention.self.key  [768 → 768]
#   roberta.encoder.layer.5.attention.self.value  [768 → 768]
#   roberta.encoder.layer.5.attention.output.dense  [768 → 768]
#   roberta.encoder.layer.5.intermediate.dense  [768 → 3072]
#   roberta.encoder.layer.5.output.dense  [3072 → 768]
#   roberta.encoder.layer.6.attention.self.query  [768 → 768]
#   roberta.encoder.layer.6.attention.self.key  [768 → 768]
#   roberta.encoder.layer.6.attention.self.value  [768 → 768]
#   roberta.encoder.layer.6.attention.output.dense  [768 → 768]
#   roberta.encoder.layer.6.intermediate.dense  [768 → 3072]
#   roberta.encoder.layer.6.output.dense  [3072 → 768]
#   roberta.encoder.layer.7.attention.self.query  [768 → 768]
#   roberta.encoder.layer.7.attention.self.key  [768 → 768]
#   roberta.encoder.layer.7.attention.self.value  [768 → 768]
#   roberta.encoder.layer.7.attention.output.dense  [768 → 768]
#   roberta.encoder.layer.7.intermediate.dense  [768 → 3072]
#   roberta.encoder.layer.7.output.dense  [3072 → 768]
#   roberta.encoder.layer.8.attention.self.query  [768 → 768]
#   roberta.encoder.layer.8.attention.self.key  [768 → 768]
#   roberta.encoder.layer.8.attention.self.value  [768 → 768]
#   roberta.encoder.layer.8.attention.output.dense  [768 → 768]
#   roberta.encoder.layer.8.intermediate.dense  [768 → 3072]
#   roberta.encoder.layer.8.output.dense  [3072 → 768]
#   roberta.encoder.layer.9.attention.self.query  [768 → 768]
#   roberta.encoder.layer.9.attention.self.key  [768 → 768]
#   roberta.encoder.layer.9.attention.self.value  [768 → 768]
#   roberta.encoder.layer.9.attention.output.dense  [768 → 768]
#   roberta.encoder.layer.9.intermediate.dense  [768 → 3072]
#   roberta.encoder.layer.9.output.dense  [3072 → 768]
#   roberta.encoder.layer.10.attention.self.query  [768 → 768]
#   roberta.encoder.layer.10.attention.self.key  [768 → 768]
#   roberta.encoder.layer.10.attention.self.value  [768 → 768]
#   roberta.encoder.layer.10.attention.output.dense  [768 → 768]
#   roberta.encoder.layer.10.intermediate.dense  [768 → 3072]
#   roberta.encoder.layer.10.output.dense  [3072 → 768]
#   roberta.encoder.layer.11.attention.self.query  [768 → 768]
#   roberta.encoder.layer.11.attention.self.key  [768 → 768]
#   roberta.encoder.layer.11.attention.self.value  [768 → 768]
#   roberta.encoder.layer.11.attention.output.dense  [768 → 768]
#   roberta.encoder.layer.11.intermediate.dense  [768 → 3072]
#   roberta.encoder.layer.11.output.dense  [3072 → 768]
#   classifier.dense  [768 → 768]
#   classifier.out_proj  [768 → 4]

# %% [markdown]
# ### 📝 TODO 5.1 — Configurar y aplicar LoRA a BERTweet

# %%
# TODO 5.1 ── LoRA sobre BERTweet
# ─────────────────────────────────────────────────────────────────────────────

# 1. Definir LoraConfig
lora_config = LoraConfig(
    task_type      = TaskType.SEQ_CLS,
    r              = 8,
    lora_alpha     = 16,
    lora_dropout   = 0.1,
    target_modules = ["query", "value"],   # proyecciones Q y V de cada capa
    modules_to_save = ["classifier"],      # cabeza clasificadora — se entrena completa
)

# 2. Aplicar LoRA
model_bertweet_lora = get_peft_model(base_bt, lora_config)
model_bertweet_lora.print_trainable_parameters()
# Out:
# trainable params: 888,580 || all params: 135,791,624 || trainable%: 0.6544

# %% [markdown]
# ### 📝 TODO 5.2 — Entrenar BERTweet-LoRA

# %%
# TODO 5.2 ── Entrenar BERTweet-LoRA
# ─────────────────────────────────────────────────────────────────────────────

trainer_lora = make_trainer(
    model        = model_bertweet_lora,
    tokenizer    = tok_bertweet,
    tokenized_ds = ds_bertweet,
    output_dir   = "./checkpoints/bertweet-lora",
    lr           = LR_LORA,
)

trainer_lora.train()

plot_training_curves(trainer_lora, title="BERTweet-LoRA — TweetEval Emotion")

metrics_bertweet_lora = full_evaluation(trainer_lora, ds_bertweet["test"])
print(metrics_bertweet_lora)
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='510' max='510' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [510/510 31:18, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1 Macro</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.971907</td>
#       <td>0.884554</td>
#       <td>0.536547</td>
#       <td>0.692513</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.578046</td>
#       <td>0.615828</td>
#       <td>0.687923</td>
#       <td>0.756684</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.507817</td>
#       <td>0.537165</td>
#       <td>0.728785</td>
#       <td>0.796791</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.488718</td>
#       <td>0.526272</td>
#       <td>0.721682</td>
#       <td>0.788770</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.453292</td>
#       <td>0.530652</td>
#       <td>0.726572</td>
#       <td>0.788770</td>
#     </tr>
#   </tbody>
# </table><p>
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ============================================================
#   Test
# ============================================================
#               precision    recall  f1-score   support
#
#        anger     0.8423    0.8996    0.8700       558
#          joy     0.8421    0.8492    0.8456       358
#     optimism     0.8193    0.5528    0.6602       123
#      sadness     0.7927    0.7906    0.7916       382
#
#     accuracy                         0.8276      1421
#    macro avg     0.8241    0.7731    0.7919      1421
# weighted avg     0.8269    0.8276    0.8246      1421
# {'test_loss': 0.520134687423706, 'test_f1_macro': 0.7918606196517148, 'test_accuracy': 0.8275862068965517, 'test_runtime': 63.5171, 'test_samples_per_second': 22.372, 'test_steps_per_second': 0.708}
